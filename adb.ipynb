# %%
import os
os.environ['PATH'] = os.path.abspath('./platform-tools/') + os.pathsep + os.environ['PATH']

# %%
$env:Path = (Resolve-Path -Path '.\platform-tools\').Path + ';' + $env:Path

# %%
# !adb install .\AuroraStore.apk
# !adb shell am start -a android.intent.action.MAIN
# !adb shell cmd package resolve-activity --brief com.aurora.store
# !adb shell am start -n com.aurora.store/.MainActivity

# %%
# !adb shell am start -n bitpit.launcher/.ui.HomeActivity

# %%
# !adb shell pm list packages -3
# Out:
# package:bitpit.launcher
# package:com.touchtype.swiftkey
# package:dev.imranr.obtainium
# package:com.mixplorer.silver
# package:com.machiav3lli.fdroid
# package:org.zwanoo.android.speedtest
# package:com.android.vending
# package:com.brave.browser
# package:com.aurora.store
# package:com.google.android.webview
# package:vn.vnnic.ispeed
# package:com.vnp.myvinaphone
# package:com.google.android.gms
# package:com.netflix.Speedtest
# package:com.looker.droidify

# %%
# !adb devices
# !adb shell df -h /data

# %%
# !adb shell pm path com.android.webview
# !adb pull /product/app/webview/webview.apk com.android.webview.apk

# !adb shell pm uninstall --user 0 com.android.webview
# !adb shell pm install-existing com.android.webview
